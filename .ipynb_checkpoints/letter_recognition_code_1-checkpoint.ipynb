# %%
import numpy as np
import pandas as pd

# %%
#importing dataset file path
import os
notebook_path = os.path.abspath("letter_recognition_code_1.ipynb")
for dirname, _, filenames in os.walk("Datasets"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Datasets\emnist-letters-test-images-idx3-ubyte
# Datasets\emnist-letters-test-labels-idx1-ubyte
# Datasets\emnist-letters-test.csv
# Datasets\emnist-letters-train-images-idx3-ubyte
# Datasets\emnist-letters-train-labels-idx1-ubyte
# Datasets\emnist-letters-train.csv

# %%
#reading csv files
testing_letter = pd.read_csv("Datasets/emnist-letters-test.csv")
training_letter = pd.read_csv("Datasets/emnist-letters-train.csv")

print(training_letter.shape)
print(testing_letter.shape)
# Out:
# (88799, 785)
# (14799, 785)

# %%
#training_letter
y1 = np.array(training_letter.iloc[:,0].values)
x1 = np.array(training_letter.iloc[:,1:].values)

#testing_letter
y2 = np.array(testing_letter.iloc[:,0].values)
x2 = np.array(testing_letter.iloc[:,1:].values)

print(y1.shape)
print(x1.shape)
# Out:
# (88799,)
# (88799, 784)

# %%
#viewing images from dataset
import matplotlib.pyplot as plt
fig,axes = plt.subplots(3,5,figsize=(10,8))
for i,ax in enumerate(axes.flat):
    ax.imshow(x1[i].reshape([28,28]))

# %%
import tensorflow as tf

# %%
#reshaping and normalizing data to be more efficient
train_images = x1 / 255.0
test_images = x2 / 255.0

train_images_number = train_images.shape[0]
train_images_height = 28
train_images_width = 28
train_images_size = train_images_height*train_images_width

train_images = train_images.reshape(train_images_number, train_images_height, train_images_width, 1)

test_images_number = test_images.shape[0]
test_images_height = 28
test_images_width = 28
test_images_size = test_images_height*test_images_width

test_images = test_images.reshape(test_images_number, test_images_height, test_images_width, 1)

#transform testing and training letters
number_of_classes = 37

y1 = tf.keras.utils.to_categorical(y1, number_of_classes)
y2 = tf.keras.utils.to_categorical(y2, number_of_classes)

# %%
#from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorlflow.keras.models import Model
#from tensorflow.keras.layers import Dense,Dropout, MaxPooling2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y = train_test_split(train_images,y1,test_size=0.2,random_state = 42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32,3,input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(number_of_classes,activation='softmax')
])

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
#callback API to save best weights and change learning rate
MCP = ModelCheckpoint('Best_points.h5',verbose=1,save_best_only=True,monitor='val_accuracy',mode='max')
ES = EarlyStopping(monitor='val_accuracy',min_delta=0,verbose=0,restore_best_weights=True,patience=3,mode='max')
RLP = ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.2,min_lr=0.0001)

# %%
history = model.fit(train_x,train_y,epochs=10,validation_data=(test_x,test_y),callbacks=[MCP,ES,RLP])
#save model
model.save('final_model.h5')
# Out:
# Epoch 1/10
# 2220/2220 [==============================] - 40s 18ms/step - loss: 0.8791 - accuracy: 0.7340 - val_loss: 0.3671 - val_accuracy: 0.8830
#
# Epoch 00001: val_accuracy improved from -inf to 0.88300, saving model to Best_points.h5
# Epoch 2/10
# 2220/2220 [==============================] - 39s 18ms/step - loss: 0.2778 - accuracy: 0.9070 - val_loss: 0.3312 - val_accuracy: 0.8995
#
# Epoch 00002: val_accuracy improved from 0.88300 to 0.89955, saving model to Best_points.h5
# Epoch 3/10
# 2220/2220 [==============================] - 40s 18ms/step - loss: 0.2011 - accuracy: 0.9327 - val_loss: 0.3509 - val_accuracy: 0.9033
#
# Epoch 00003: val_accuracy improved from 0.89955 to 0.90332, saving model to Best_points.h5
# Epoch 4/10
# 2220/2220 [==============================] - 40s 18ms/step - loss: 0.1678 - accuracy: 0.9412 - val_loss: 0.3819 - val_accuracy: 0.8977
#
# Epoch 00004: val_accuracy did not improve from 0.90332
# Epoch 5/10
# 2220/2220 [==============================] - 40s 18ms/step - loss: 0.1508 - accuracy: 0.9478 - val_loss: 0.4061 - val_accuracy: 0.9041
#
# Epoch 00005: val_accuracy improved from 0.90332 to 0.90405, saving model to Best_points.h5
# Epoch 6/10
# 2220/2220 [==============================] - 39s 18ms/step - loss: 0.0831 - accuracy: 0.9680 - val_loss: 0.3627 - val_accuracy: 0.9145
#
# Epoch 00006: val_accuracy improved from 0.90405 to 0.91447, saving model to Best_points.h5
# Epoch 7/10
# 2220/2220 [==============================] - 39s 18ms/step - loss: 0.0604 - accuracy: 0.9772 - val_loss: 0.4004 - val_accuracy: 0.9131
#
# Epoch 00007: val_accuracy did not improve from 0.91447
# Epoch 8/10
# 2220/2220 [==============================] - 39s 18ms/step - loss: 0.0539 - accuracy: 0.9789 - val_loss: 0.4133 - val_accuracy: 0.9110
#
# Epoch 00008: val_accuracy did not improve from 0.91447
# Epoch 9/10
# 2220/2220 [==============================] - 39s 18ms/step - loss: 0.0490 - accuracy: 0.9809 - val_loss: 0.4269 - val_accuracy: 0.9140
#
# Epoch 00009: val_accuracy did not improve from 0.91447

# %%
#plot accuracy vs val_accuracy
import seaborn as sns

# %%
q = len(history.history['accuracy'])

plt.figsize=(10,10)
sns.lineplot(x = range(1,1+q),y = history.history['accuracy'], label='Accuracy')
sns.lineplot(x = range(1,1+q),y = history.history['val_accuracy'], label='Val_Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
import matplotlib.image as mpimg
predictions = model.predict([test_x])
print(np.argmax(predictions[500]))

plt.imshow(test_x[500], cmap="gray")
plt.show()

#classify newly introduced image
#from tensorflow import keras
#from tf.keras.preprocessing.image import load_img
#from tf.keras.preprocessing.image import img_to_array
#from keras.datasets import mnist
#from keras.models import load_model
#import matplotlib.image as mpimg
show_img1 = mpimg.imread("new_images/mlproject_image14.png")
imgplot1 = plt.imshow(show_img1)
plt.show()

#load, convert, and reshape image
def load_image(filename):
    #no grayscale
    #img1 = tf.keras.preprocessing.image.load_img(filename, target_size=(28,28))# grayscale=True, color_mode = "grayscale", target_size=(28,28))
    #grayscale
    img1 = tf.keras.preprocessing.image.load_img(filename, grayscale=True, color_mode = "grayscale", target_size=(28,28))
    img1_2 = img1
    imgplot2 = plt.imshow(img1_2)
    plt.show()
    img1 = tf.keras.preprocessing.image.img_to_array(img1)
    #img1 = img1.reshape(1, 28, 28, 1)
    img1 = img1 / 255.0
    img1_number = img1.shape[0]
    #print(img1)
    img1_height = 28
    img1_width = 28
    #no grayscale
    #img1 = img1.reshape(3, img1_height, img1_width, 1)
    #grayscale
    img1 = img1.reshape(1, img1_height, img1_width, 1)
    #img1 = img1.astype('float32')
    #img1 = img1 / 255.0
    return img1

#load image and classify the class(letter)
def run_img1():
    img1 = load_image("new_images/mlproject_image14.png")
    #img1_2 = tf.keras.preprocessing.image.array_to_img(img1)
    #img1_2.show()
    model1 = tf.keras.models.load_model('Best_points.h5')
    letter1 = model1.predict_classes(img1, batch_size=1, verbose=0)
    print(letter1[0])
    model2 = tf.keras.models.load_model('final_model.h5')
    letter2 = model2.predict_classes(img1, batch_size=1, verbose=0)
    print(letter2[0])
    
run_img1()
# Out:
# 3
# c:\users\chris\appdata\local\programs\python\python39\lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# 3
# 3
