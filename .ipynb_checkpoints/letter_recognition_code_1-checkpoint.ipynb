# %%
import numpy as np
import pandas as pd

# %%
#importing dataset file path
import os
notebook_path = os.path.abspath("letter_recognition_code_1.ipynb")
for dirname, _, filenames in os.walk("Datasets"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Datasets\emnist-letters-test-images-idx3-ubyte
# Datasets\emnist-letters-test-labels-idx1-ubyte
# Datasets\emnist-letters-test.csv
# Datasets\emnist-letters-train-images-idx3-ubyte
# Datasets\emnist-letters-train-labels-idx1-ubyte
# Datasets\emnist-letters-train.csv

# %%
#reading csv files
train_letters = pd.read_csv("Datasets/emnist-letters-train.csv")
test_letters = pd.read_csv("Datasets/emnist-letters-test.csv")

print(train_letters.shape)
print(test_letters.shape)
# Out:
# (88799, 785)
# (14799, 785)

# %%
#train_letters
y1 = np.array(train_letters.iloc[:,0].values)
x1 = np.array(train_letters.iloc[:,1:].values)

#test_letters
y2 = np.array(test_letters.iloc[:,0].values)
x2 = np.array(test_letters.iloc[:,1:].values)

#train_letters
print(y1.shape)
print(x1.shape)

#test_letters
print(y2.shape)
print(x2.shape)
# Out:
# (88799,)
# (88799, 784)
# (14799,)
# (14799, 784)

# %%
import matplotlib.pyplot as plt

#viewing training images from dataset
fig,axes = plt.subplots(3,5,figsize=(10,8))
for i,ax in enumerate(axes.flat):
    ax.imshow(x1[i].reshape([28,28]))

# %%
import matplotlib.pyplot as plt

#viewing testing images from dataset
#want to view to make sure the test set differs from the train set to avoid potential overfitting
fig,axes = plt.subplots(3,5,figsize=(10,8))
for j,bx in enumerate(axes.flat):
    bx.imshow(x2[j].reshape([28,28]))

# %%
import tensorflow as tf

#reshaping and normalizing data to be more efficient
train_images = x1 / 255.0
test_images = x2 / 255.0

train_images_number = train_images.shape[0]
train_images_height = 28
train_images_width = 28
train_images_size = train_images_height*train_images_width

train_images = train_images.reshape(train_images_number,train_images_height,train_images_width,1)

test_images_number = test_images.shape[0]
test_images_height = 28
test_images_width = 28
test_images_size = test_images_height*test_images_width

test_images = test_images.reshape(test_images_number,test_images_height,test_images_width,1)

#transform testing and training letters
#original number of classes
#tried 26 but was out of bounds
#tried other values but errors
number_of_classes = 37

y1 = tf.keras.utils.to_categorical(y1,number_of_classes)
y2 = tf.keras.utils.to_categorical(y2,number_of_classes)

# %%
from sklearn.model_selection import train_test_split

#split train and test input
train_x,test_x,train_y,test_y = train_test_split(train_images,y1,test_size=0.2,train_size=0.8,random_state=62)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, MaxPooling2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32,3,input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(number_of_classes,activation='softmax')
])

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
#callback API to save best weights and change learning rate
MCP = ModelCheckpoint('Best_points.h5',verbose=1,save_best_only=True,monitor='val_accuracy',mode='max')
ES = EarlyStopping(monitor='val_accuracy',min_delta=0,verbose=0,restore_best_weights=True,patience=3,mode='max')
RLP = ReduceLROnPlateau(monitor='val_loss',patience=1,factor=0.05,min_lr=0.0001)

# %%
history = model.fit(train_x,train_y,epochs=10,validation_data=(test_x,test_y),callbacks=[MCP,ES,RLP])

#save as a new model to make sure the model is correct after callbacks
model.save('final_model.h5')
# Out:
# Epoch 1/10
# 2220/2220 [==============================] - 42s 19ms/step - loss: 0.8944 - accuracy: 0.7308 - val_loss: 0.3517 - val_accuracy: 0.8891
#
# Epoch 00001: val_accuracy improved from -inf to 0.88913, saving model to Best_points.h5
# Epoch 2/10
# 2220/2220 [==============================] - 42s 19ms/step - loss: 0.2815 - accuracy: 0.9090 - val_loss: 0.3145 - val_accuracy: 0.9051
#
# Epoch 00002: val_accuracy improved from 0.88913 to 0.90507, saving model to Best_points.h5
# Epoch 3/10
# 2220/2220 [==============================] - 42s 19ms/step - loss: 0.2024 - accuracy: 0.9322 - val_loss: 0.3273 - val_accuracy: 0.8992
#
# Epoch 00003: val_accuracy did not improve from 0.90507
# Epoch 4/10
# 2220/2220 [==============================] - 41s 18ms/step - loss: 0.1110 - accuracy: 0.9601 - val_loss: 0.2735 - val_accuracy: 0.9236
#
# Epoch 00004: val_accuracy improved from 0.90507 to 0.92365, saving model to Best_points.h5
# Epoch 5/10
# ...

# %%
import seaborn as sns

#plot accuracy vs epochs
q = len(history.history['accuracy'])

plt.figsize=(10,10)
sns.lineplot(x=range(1,1+q),y=history.history['accuracy'],label='Accuracy')
sns.lineplot(x=range(1,1+q),y=history.history['val_accuracy'],label='Val_Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
#test the model against a handrawn letter/image
#note - the model returns a numeric class versus an alphabet character class
#need to grab an image from the test dataset, output its class, hand draw a similar shape/letter, and test the model against it
#numeric matching classes between the test image and the handrawn image confirms the model is working and recognizing letters

import matplotlib.image as mpimg

#display an image from the test letters dataset
plt.imshow(test_x[500], cmap="gray")
print("Image of letter from test_letters")
plt.show()

predictions = model.predict([test_x])
print("The above image is Class: ",np.argmax(predictions[500]))
print("")


#classify newly introduced image

#from tensorflow import keras
#from tf.keras.preprocessing.image import load_img
#from tf.keras.preprocessing.image import img_to_array
#from keras.datasets import mnist
#from keras.models import load_model
#import matplotlib.image as mpimg

#display handrawn image
#used similar backround and font colors to match the training/testing images
show_img1 = mpimg.imread("new_images/mlproject_image19.png")
imgplot1 = plt.imshow(show_img1)
print("Handrawn letter to verify correct classification from test_letters image")
plt.show()

#convert and reshape handrawn image
def load_image(filename):
    
    #convert handrawn image
    #no grayscale
    #img1 = tf.keras.preprocessing.image.load_img(filename, target_size=(28,28))# grayscale=True, color_mode = "grayscale", target_size=(28,28))
    #grayscale
    img1 = tf.keras.preprocessing.image.load_img(filename, grayscale=True, color_mode = "grayscale", target_size=(28,28))
    img1_2 = img1
    imgplot2 = plt.imshow(img1_2)
    print("Handrawn letter converted to grayscale")
    #display handrawn letter converted to grayscale
    plt.show()
    
    #reshape handrawn image
    img1 = tf.keras.preprocessing.image.img_to_array(img1)
    #img1 = img1.reshape(1, 28, 28, 1)
    img1 = img1 / 255.0
    img1_number = img1.shape[0]
    #print(img1)
    img1_height = 28
    img1_width = 28
    #no grayscale
    #img1 = img1.reshape(3, img1_height, img1_width, 1)
    #grayscale
    img1 = img1.reshape(1, img1_height, img1_width, 1)
    #img1 = img1.astype('float32')
    #img1 = img1 / 255.0
    
    return img1

#load image and classify the class(letter)
def run_img1():
    
    #load handrawn image
    img1 = load_image("new_images/mlproject_image19.png")
    #img1_2 = tf.keras.preprocessing.image.array_to_img(img1)
    #img1_2.show()
    
    #load and apply Best_points model to the handrawn image
    model1 = tf.keras.models.load_model('Best_points.h5')
    letter1 = model1.predict_classes(img1, batch_size=1, verbose=0)
    print("Best_points.h5 returns Class: ",letter1[0])
    
    #load and apply final_model model to the handrawn image
    model2 = tf.keras.models.load_model('final_model.h5')
    letter2 = model2.predict_classes(img1, batch_size=1, verbose=0)
    print("final_model.h5 returns Class: ",letter2[0])
    
    
#test Best_points and final_model models against the handrawn image
run_img1()
# Out:
# Image of letter from test_letters
# The above image is Class:  5
#
# Handrawn letter to verify correct classification from test_letters image
# Handrawn letter converted to grayscale
# Best_points.h5 returns Class:  6
# final_model.h5 returns Class:  6
